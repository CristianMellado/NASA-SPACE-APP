# %% [markdown]
# <a href="https://colab.research.google.com/github/CristianMellado/NASA-SPACE-APP/blob/main/ai_crater_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# YOLOv5
# !pip install -q torch torchvision torchaudio
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -qr requirements.txt

import torch
from IPython.display import Image, display

#trained model
model_path = '/content/drive/MyDrive/NASAA/craters/best.pt'
model = torch.hub.load('ultralytics/yolov5', 'custom', path=model_path, force_reload=True)

print("Clases detectadas:", model.names)
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17582, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 17582 (delta 0), reused 0 (delta 0), pack-reused 17579 (from 2)
# Receiving objects: 100% (17582/17582), 16.86 MiB | 16.39 MiB/s, done.
# Resolving deltas: 100% (11973/11973), done.
# /content/yolov5/yolov5/yolov5
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2025-10-6 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 378 layers, 35248920 parameters, 0 gradients, 48.9 GFLOPs
# Adding AutoShape...
# Clases detectadas: {0: 'Crater'}

# %%
# predicciones
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/crater1luna.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp
# 📁 Mostrando imagen detectada desde: runs/detect/exp

# %%
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/crater2luna.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp2
# 📁 Mostrando imagen detectada desde: runs/detect/exp2

# %%
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/crater3luna.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp3
# 📁 Mostrando imagen detectada desde: runs/detect/exp3

# %%
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/crater4luna.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp4
# 📁 Mostrando imagen detectada desde: runs/detect/exp4

# %%
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/crater5luna.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp5
# 📁 Mostrando imagen detectada desde: runs/detect/exp5

# %%
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/nocrater3luna.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp6
# 📁 Mostrando imagen detectada desde: runs/detect/exp6

# %%
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/crater1marte.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp7
# 📁 Mostrando imagen detectada desde: runs/detect/exp7

# %%
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/crater2marte.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp8
# 📁 Mostrando imagen detectada desde: runs/detect/exp8

# %%
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/crater3marte.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp9
# 📁 Mostrando imagen detectada desde: runs/detect/exp9

# %%
img_path = '/content/drive/MyDrive/NASAA/craters/pruebas/img_negra.jpeg'

results = model(img_path)
results.save()

import glob, os
from IPython.display import Image, display

last_exp = sorted(glob.glob('runs/detect/exp*'))[-1]

result_images = glob.glob(os.path.join(last_exp, '*.*'))

if len(result_images) == 0:
    print("⚠️ No se encontró ninguna imagen resultante en:", last_exp)
else:
    print(f"📁 Mostrando imagen detectada desde: {last_exp}")
    display(Image(filename=result_images[0]))
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp10
# 📁 Mostrando imagen detectada desde: runs/detect/exp9
